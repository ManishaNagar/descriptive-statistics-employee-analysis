# %% [markdown]
# # Employee Data Analysis using Descriptive Statistics
#
# This project analyzes employee dataset using Python, Pandas, Matplotlib, and Seaborn to understand salary, age, and lifestyle patterns.

# %% [markdown]
# In this exercise, you will perform the following tasks:
# 1. Load and study the data
# 2. Visualise the distributions of ratings and compensations
# 3. Subset the data based on threshold

# %% [markdown]
# # Task 1 - Load and study the data
# Load the data and study its features such as:
#
# *   The number of employees
# *   The number of features
# *   The types of features

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the "Employee Dataset" file as a Pandas DataFrame

data = pd.read_csv('/content/Employee Dataset.csv')

# %% [markdown]
# ## Dataset Overview
# This dataset contains information about employees including:
# - Age
# - Salary
# - Healthy eating score
# - Active lifestyle score
# - Group category
#
# Total records: 50 employees

# %%
# Take a brief look at data

data.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
# Get the dimensions of the dataFrame

data.shape
# Out:
# (50, 6)

# %%
# Describe the dataset

data.describe()
# Out:
#              id        age  healthy_eating  active_lifestyle       salary
# count  50.00000  50.000000       50.000000         50.000000    50.000000
# mean   24.50000  31.880000        4.920000          5.900000  2027.500000
# std    14.57738   8.390082        1.827678          2.022829  1076.861885
# min     0.00000  22.000000        1.000000          1.000000   556.000000
# 25%    12.25000  26.250000        3.250000          5.000000  1134.000000
# 50%    24.50000  30.000000        5.000000          6.000000  1950.000000
# 75%    36.75000  35.750000        6.000000          7.000000  2732.250000
# max    49.00000  62.000000        9.000000         10.000000  4969.000000

# %% [markdown]
# This shows:
#
# mean
#
# min
#
# max
#
# standard deviation

# %%
# Get the row name of the dataFrame

data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataFrame

data.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
# Look at the basic information about the dataFrame

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# # Observations from Task 1
# There are 50 rows and 6 columns in the data. Each row contains the employee specifics of a certain employee in the company
#
# The features in the data set are:
# 1. The id of the employee
# 2. Their respective groups are age
# 3. Their healthy_eating and active_lifestyle
# 4. Their salary

# %% [markdown]
# # Task 2 - Visualise the distributions of ratings and compensations
# We will now visualise the distributions of employee ratings and compensations
#
# We will create the following plots:
# *   A scatter plot of employee age and employee salary, healthy_eating and active_lifestyle, health_eating and salary
# *   A count plot of groups
# *   A histogram of employee salary

# %%
# Create a scatter plot of the "Age" and "Employee Salary" features

plt.figure(figsize = (11,6))

sns.scatterplot(data = data, x = 'age', y = 'salary', color = 'blue',
                edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Employee Age v/s Employee salary")
plt.xlabel('Employee Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Observations:
# We observe that in general, there is a relationship between age and Salary of employee
#
# As age increases, the Salary also increases, though there are some outliers present as well

# %%
# Create a scatter plot of the "healthy_eating" and "active_lifestyle" features

plt.figure(figsize = (11,6))

sns.scatterplot(data = data, x = 'healthy_eating', y = 'active_lifestyle', color = 'red',
                edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Healthy Eating v/s Active Lifestyle")
plt.xlabel("Healthy Eating")
plt.ylabel("Active Lifestyle")
plt.show()

# %% [markdown]
# # observations:
# We observe that in general, there ais a relationship between healthy_eating and active_eating of employee
#
# As healthy_eating increases, the active_lifestyle also increases

# %%
# Create a scatter plot of the "healthy_ eating" and "salary" features

plt.figure(figsize = (11,6))

sns.scatterplot(data = data, x = 'healthy_eating', y = 'salary', color = 'green',
                edgecolor = 'linen', alpha = 0.5)

plt.title("Scatter Plot of Healthy Eating v/s Salary")
plt.xlabel('Healthy Eating')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # observations
# We observe that in general, there is a relationship between healthy_eating and salary of employee
#
# As healthy_eating increases, the salary also increases

# %%
# Create a count plot of the "groups" feature

plt.figure(figsize = (10,5))

sns.countplot(data = data, x = 'groups', edgecolor = 'linen', alpha = 0.7)

plt.title("Count Plot of Groups")
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Observations:
#
# We see that most employees either belong to Group O, with group A having maximum frequency

# %%
# Create a histogram of the "Salary" feature

plt.figure(figsize = (11,6))

sns.histplot(data = data, x = 'salary', color = 'orange',
             edgecolor = 'linen', alpha = 0.7, bins = 10)

plt.title("Histogram of salary")
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Observations:
# We see that the salaries are not uniform, which is not necessarily a discrepancy
#
# But we do observe that there are employees with salaries on either extremities of the histogram
#
# Based on the histogram, we can see that the count of highest earning employee is very less

# %% [markdown]
# # Observations from Task 2
# 1. Generally, as the employee's age increase, there is an increase in the employee salary
# 2. Generally, as the employee's health_eating habit increase, there is an increase in the employee salary as well
# 3. However, the employee salary values are more spread out
# 4. An employee of healthy_eating greater that 8 can be taken as 8 only
# 5. An employee salary less than 1000 can be considered as a lower salary

# %% [markdown]
# # Task 3 - Subset the data based on thresholds
# We will now subset the original data frame based on the following conditions:
#
# *   Employees with healthy_eating greater than 8
# *   Employees with Salary less than 1000
# *   Employees with healthy_eating greater than 8 and with salary less than 1000

# %%
# Employee healthy_eating is greater than 8

sub1 = data[data['healthy_eating'] > 8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
# Salary less than 1000

sub2 = data[data['salary'] < 1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
# Employees with healthy_eating greater than 8 and with salary less than 1000

sub = data[(data['healthy_eating'] > 8) & (data['healthy_eating'] < 1000)]
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# # Observations:
# 1. The only employee seemingly facing a discrepancy in salary as compared to healthy_eating is employee who is having id = 26
# 2. The employee with id having 26 has a salary of 700

# %% [markdown]
# ## Correlation Analysis
#
# Correlation heatmap shows relationship between different numerical variables.
#
# Values close to:
# - +1 → strong positive correlation
# - -1 → strong negative correlation
# - 0 → weak correlation
#
# This helps understand how salary relates to age and lifestyle factors.

# %%
# Correlation Heatmap Analysis

import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_data = data.select_dtypes(include=['number'])

plt.figure(figsize=(6,4))

sns.heatmap(numeric_data.corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap of Employee Dataset")

plt.show()

# %% [markdown]
# ## Final Conclusion
#
# From this analysis, we found:
#
# - Salary tends to increase with age
# - Healthy lifestyle has slight positive relation with salary
# - Most employees belong to specific groups
# - Some employees have lower salary despite good health scores
#
# Descriptive statistics and visualization helped identify important employee patterns.
#
# This analysis can help organizations understand employee characteristics and compensation trends.
